# %%
from NniDbQuery import nni_query

nni_query('../nni_check.sqlite', show=True)
# Out:
# [('POB3Y', 0, '"{\\"default\\": 15.0, \\"training acc.\\": 14.0816, \\"val. loss\\": 1.88155, \\"train. loss\\": 1.96062}"'), ('POB3Y', 1, '"{\\"default\\": 29.6429, \\"training acc.\\": 19.6939, \\"val. loss\\": 1.99114, \\"train. loss\\": 1.89353}"'), ('POB3Y', 2, '"{\\"default\\": 32.1429, \\"training acc.\\": 32.0408, \\"val. loss\\": 2.22819, \\"train. loss\\": 1.8145}"'), ('POB3Y', 3, '"{\\"default\\": 40.0, \\"training acc.\\": 41.1224, \\"val. loss\\": 1.73776, \\"train. loss\\": 1.70614}"'), ('POB3Y', 4, '"{\\"default\\": 46.0714, \\"training acc.\\": 48.1633, \\"val. loss\\": 1.7885, \\"train. loss\\": 1.50697}"'), ('POB3Y', 5, '"{\\"default\\": 48.5714, \\"training acc.\\": 51.6327, \\"val. loss\\": 1.67558, \\"train. loss\\": 1.43468}"'), ('POB3Y', 6, '"{\\"default\\": 55.3571, \\"training acc.\\": 58.1633, \\"val. loss\\": 1.60023, \\"train. loss\\": 1.3402}"'), ('POB3Y', 7, '"{\\"default\\": 56.4286, \\"training acc.\\": 62.551, \\"val. loss\\": 1.52546, \\"train. loss\
# ...
