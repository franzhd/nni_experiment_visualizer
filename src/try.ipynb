# %%
placeholders = ', '.join(_ for _ in ['uno','due', 'tre'])
print(placeholders)
# Out:
# uno, due, tre

# %%
from NniDbQuery import nni_query

nni_query('../nni.sqlite', show=True)
# Out:
# found single Score
# +---------------+------------+------------+-------------+--------------+----------+---------+
# | Trials Name   |   treshold |   tau_grad |   true_rate |   batch_size |       lr |   Score |
# +===============+============+============+=============+==============+==========+=========+
# | y10NU         |  0.0177617 |   0.446847 |       0.725 |           80 | 0.000395 | 80.9392 |
# +---------------+------------+------------+-------------+--------------+----------+---------+
# | pC72J         |  0.0878094 |   0.401349 |       0.8   |           64 | 0.000435 | 80.5387 |
# +---------------+------------+------------+-------------+--------------+----------+---------+
# | YkZ8W         |  0.166498  |   0.481023 |       0.85  |           64 | 0.000505 | 80.511  |
# +---------------+------------+------------+-------------+--------------+----------+---------+
# | PBQ7D         |  0.13416   |   0.435289 |       0.825 |           64 | 0.00044  | 80.4972 |
# ...

# %%
nni_query('../nni_check.sqlite', show=True)
# Out:
# found multiple metrics, tracking only default
# +---------------+-------------+-----------+-------------+----------+------------+-------+----------+----------+---------+---------+
# | Trials Name   |   nb_hidden |   alpha_r |   alpha_out |   beta_r |   beta_out |    lr |   reg_l1 |   reg_l2 |   slope |   Score |
# +===============+=============+===========+=============+==========+============+=======+==========+==========+=========+=========+
# | POB3Y         |          48 |      0.1  |        0.8  |     0.75 |        0.4 | 0.002 |   0.0003 |    0     |      15 | 93.5714 |
# +---------------+-------------+-----------+-------------+----------+------------+-------+----------+----------+---------+---------+
# | bb3hK         |          41 |      0.25 |        0.25 |     0.95 |        1   | 0.001 |   0.0008 |    5e-06 |      20 | 93.5714 |
# +---------------+-------------+-----------+-------------+----------+------------+-------+----------+----------+---------+---------+
# ...
